# %%
from pathlib import Path
import numpy as np
import pandas as pd

# %%
path = Path('../data')

# %%
# !ls ../data/annotations/
# Out:
# captions_train2014.json   instances_val2014.json
# captions_val2014.json	  person_keypoints_train2014.json
# instances_train2014.json  person_keypoints_val2014.json

# %%
import json

# %%
with open(path/'annotations/captions_train2014.json') as json_data:
    data_trn = json.load(json_data)

with open(path/'annotations/captions_val2014.json') as json_data:
    data_val = json.load(json_data)

# %%
data_trn.keys()
# Out:
# dict_keys(['info', 'images', 'licenses', 'annotations'])

# %%
data_trn['annotations'][0],data_trn['images'][0]
# Out:
# ({'image_id': 318556,
#   'id': 48,
#   'caption': 'A very clean and well decorated empty bathroom'},
#  {'license': 5,
#   'file_name': 'COCO_train2014_000000057870.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2014/COCO_train2014_000000057870.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-14 16:28:13',
#   'flickr_url': 'http://farm4.staticflickr.com/3153/2970773875_164f0c0b83_z.jpg',
#   'id': 57870})

# %%
df_file_name_trn.loc[318556]
# Out:
# coco_url         http://images.cocodataset.org/train2014/COCO_t...
# date_captured                                  2013-11-15 05:00:35
# file_name                          COCO_train2014_000000318556.jpg
# flickr_url       http://farm4.staticflickr.com/3133/3378902101_...
# height                                                         640
# license                                                          1
# width                                                          480
# Name: 318556, dtype: object

# %%
df_cap_trn.iloc[0]
# Out:
# caption    A very clean and well decorated empty bathroom
# id                                                     48
# Name: 318556, dtype: object

# %%
df_cap_trn = pd.DataFrame(data_trn['annotations'])
df_file_name_trn = pd.DataFrame(data_trn['images'])
df_cap_trn = df_cap_trn.set_index('image_id')
df_file_name_trn = df_file_name_trn.set_index('id')
df_trn = df_cap_trn.join(df_file_name_trn,how='outer')
#df_val = pd.DataFrame(data_val['annotations'])

# %%
df_trn.head()
# Out:
#                                              caption      id  \
# 9  Closeup of bins of food that include broccoli ...  661611
# 9  A meal is presented in brightly colored plasti...  661977
# 9  there are containers filled with different kin...  663627
# 9  Colorful dishes holding meat, vegetables, frui...  666765
# 9         A bunch of trays that have different food.  667602
#
#                                             coco_url        date_captured  \
# 9  http://images.cocodataset.org/train2014/COCO_t...  2013-11-19 20:40:11
# 9  http://images.cocodataset.org/train2014/COCO_t...  2013-11-19 20:40:11
# 9  http://images.cocodataset.org/train2014/COCO_t...  2013-11-19 20:40:11
# 9  http://images.cocodataset.org/train2014/COCO_t...  2013-11-19 20:40:11
# 9  http://images.cocodataset.org/train2014/COCO_t...  2013-11-19 20:40:11
#
#                          file_name  \
# 9  COCO_train2014_000000000009.jpg
# 9  COCO_train2014_000000000009.jpg
# 9  COCO_train2014_000000000009.jpg
# 9  COCO_train2014_000000000009.jpg
# 9  COCO_train2014_000000000009.jpg
#
#                                           flickr_url  height  license  width
# 9  http://farm5.staticflickr.com/4026/4622125393_...     480        3    640
# 9  http://farm5.staticflickr.com/4026/4622125393_...     480        3    640
# 9  http://farm5.staticflickr.com/4026/4622125393_...     480        3    640
# 9  http://farm5.staticflickr.com/4026/4622125393_...     480        3    640
# 9  http://farm5.staticflickr.com/4026/4622125393_...     480        3    640

# %%
df_cap_val = pd.DataFrame(data_val['annotations'])
df_file_name_val = pd.DataFrame(data_val['images'])
df_cap_val = df_cap_val.set_index('image_id')
df_file_name_val = df_file_name_val.set_index('id')
df_val = df_cap_val.join(df_file_name_val,how='outer')
df_val.head()
#df_val = pd.DataFrame(data_val['annotations'])
# Out:
#                                               caption      id  \
# 42  This wire metal rack holds several pairs of sh...  641613
# 42        A dog sleeping on a show rack in the shoes.  645309
# 42  Various slides and other footwear rest in a me...  650217
# 42       A small dog is curled up on top of the shoes  650868
# 42  a shoe rack with some shoes and a dog sleeping...  652383
#
#                                              coco_url        date_captured  \
# 42  http://images.cocodataset.org/val2014/COCO_val...  2013-11-18 09:22:23
# 42  http://images.cocodataset.org/val2014/COCO_val...  2013-11-18 09:22:23
# 42  http://images.cocodataset.org/val2014/COCO_val...  2013-11-18 09:22:23
# 42  http://images.cocodataset.org/val2014/COCO_val...  2013-11-18 09:22:23
# 42  http://images.cocodataset.org/val2014/COCO_val...  2013-11-18 09:22:23
#
#                         file_name  \
# 42  COCO_val2014_000000000042.jpg
# 42  COCO_val2014_000000000042.jpg
# 42  COCO_val2014_000000000042.jpg
# 42  COCO_val2014_000000000042.jpg
# 42  COCO_val2014_000000000042.jpg
#
#                                            flickr_url  height  license  width
# 42  http://farm7.staticflickr.com/6024/6016274664_...     478        2    640
# 42  http://farm7.staticflickr.com/6024/6016274664_...     478        2    640
# 42  http://farm7.staticflickr.com/6024/6016274664_...     478        2    640
# 42  http://farm7.staticflickr.com/6024/6016274664_...     478        2    640
# 42  http://farm7.staticflickr.com/6024/6016274664_...     478        2    640

# %%
from PIL import Image

# %%
Image.open(path/'train2014/COCO_train2014_000000000009.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480 at 0x7F14702234E0>

# %%
from inceptionv4 import *

# %%
encoder = inceptionv4()

# %%
encoder
# Out:
# InceptionV4(
#   (features): Sequential(
#     (0): BasicConv2d(
#       (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (1): BasicConv2d(
#       (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (2): BasicConv2d(
#       (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (3): Mixed_3a(
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (conv): BasicConv2d(
#         (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(2, 2), bias=False)
#         (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#       )
#     )
#     (4): Mixed_4a(
#       (block0): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(160, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#       )
#       (block1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(160, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(64, 64, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(64, 64, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (3): BasicConv2d(
#           (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#       )
#     )
#     (5): Mixed_5a(
#       (conv): BasicConv2d(
#         (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), bias=False)
#         (bn): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#       )
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (6): Inception_A(
#       (block0): BasicConv2d(
#         (conv): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#       )
#       (block1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#       )
#       (block2): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#       )
#       (block3): Sequential(
#         (0): AvgPool2d(kernel_size=3, stride=1, padding=1)
#         (1): BasicConv2d(
#           (conv): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#       )
#     )
#     (7): Inception_A(
#       (block0): BasicConv2d(
#         (conv): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#       )
#       (block1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#       )
#       (block2): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#       )
#       (block3): Sequential(
#         (0): AvgPool2d(kernel_size=3, stride=1, padding=1)
#         (1): BasicConv2d(
#           (conv): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#       )
#     )
#     (8): Inception_A(
#       (block0): BasicConv2d(
#         (conv): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#       )
#       (block1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#       )
#       (block2): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#       )
#       (block3): Sequential(
#         (0): AvgPool2d(kernel_size=3, stride=1, padding=1)
#         (1): BasicConv2d(
#           (conv): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#       )
#     )
#     (9): Inception_A(
#       (block0): BasicConv2d(
#         (conv): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#       )
#       (block1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#       )
#       (block2): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#       )
#       (block3): Sequential(
#         (0): AvgPool2d(kernel_size=3, stride=1, padding=1)
#         (1): BasicConv2d(
#           (conv): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#       )
#     )
#     (10): Reduction_A(
#       (block0): BasicConv2d(
#         (conv): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), bias=False)
#         (bn): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#       )
#       (block1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(192, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(224, 256, kernel_size=(3, 3), stride=(2, 2), bias=False)
#           (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#       )
#       (block2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (11): Inception_B(
#       (block0): BasicConv2d(
#         (conv): Conv2d(1024, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#       )
#       (block1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(1024, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(192, 224, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(224, 256, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#       )
#       (block2): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(1024, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(192, 224, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (3): BasicConv2d(
#           (conv): Conv2d(224, 224, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (4): BasicConv2d(
#           (conv): Conv2d(224, 256, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#       )
#       (block3): Sequential(
#         (0): AvgPool2d(kernel_size=3, stride=1, padding=1)
#         (1): BasicConv2d(
#           (conv): Conv2d(1024, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#       )
#     )
#     (12): Inception_B(
#       (block0): BasicConv2d(
#         (conv): Conv2d(1024, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#       )
#       (block1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(1024, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(192, 224, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(224, 256, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#       )
#       (block2): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(1024, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(192, 224, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (3): BasicConv2d(
#           (conv): Conv2d(224, 224, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (4): BasicConv2d(
#           (conv): Conv2d(224, 256, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#       )
#       (block3): Sequential(
#         (0): AvgPool2d(kernel_size=3, stride=1, padding=1)
#         (1): BasicConv2d(
#           (conv): Conv2d(1024, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#       )
#     )
#     (13): Inception_B(
#       (block0): BasicConv2d(
#         (conv): Conv2d(1024, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#       )
#       (block1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(1024, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(192, 224, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(224, 256, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#       )
#       (block2): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(1024, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(192, 224, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (3): BasicConv2d(
#           (conv): Conv2d(224, 224, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (4): BasicConv2d(
#           (conv): Conv2d(224, 256, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#       )
#       (block3): Sequential(
#         (0): AvgPool2d(kernel_size=3, stride=1, padding=1)
#         (1): BasicConv2d(
#           (conv): Conv2d(1024, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#       )
#     )
#     (14): Inception_B(
#       (block0): BasicConv2d(
#         (conv): Conv2d(1024, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#       )
#       (block1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(1024, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(192, 224, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(224, 256, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#       )
#       (block2): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(1024, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(192, 224, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (3): BasicConv2d(
#           (conv): Conv2d(224, 224, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (4): BasicConv2d(
#           (conv): Conv2d(224, 256, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#       )
#       (block3): Sequential(
#         (0): AvgPool2d(kernel_size=3, stride=1, padding=1)
#         (1): BasicConv2d(
#           (conv): Conv2d(1024, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#       )
#     )
#     (15): Inception_B(
#       (block0): BasicConv2d(
#         (conv): Conv2d(1024, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#       )
#       (block1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(1024, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(192, 224, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(224, 256, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#       )
#       (block2): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(1024, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(192, 224, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (3): BasicConv2d(
#           (conv): Conv2d(224, 224, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (4): BasicConv2d(
#           (conv): Conv2d(224, 256, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#       )
#       (block3): Sequential(
#         (0): AvgPool2d(kernel_size=3, stride=1, padding=1)
#         (1): BasicConv2d(
#           (conv): Conv2d(1024, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#       )
#     )
#     (16): Inception_B(
#       (block0): BasicConv2d(
#         (conv): Conv2d(1024, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#       )
#       (block1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(1024, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(192, 224, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(224, 256, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#       )
#       (block2): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(1024, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(192, 224, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (3): BasicConv2d(
#           (conv): Conv2d(224, 224, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (4): BasicConv2d(
#           (conv): Conv2d(224, 256, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#       )
#       (block3): Sequential(
#         (0): AvgPool2d(kernel_size=3, stride=1, padding=1)
#         (1): BasicConv2d(
#           (conv): Conv2d(1024, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#       )
#     )
#     (17): Inception_B(
#       (block0): BasicConv2d(
#         (conv): Conv2d(1024, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#       )
#       (block1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(1024, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(192, 224, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(224, 256, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#       )
#       (block2): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(1024, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(192, 224, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (3): BasicConv2d(
#           (conv): Conv2d(224, 224, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (4): BasicConv2d(
#           (conv): Conv2d(224, 256, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#       )
#       (block3): Sequential(
#         (0): AvgPool2d(kernel_size=3, stride=1, padding=1)
#         (1): BasicConv2d(
#           (conv): Conv2d(1024, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#       )
#     )
#     (18): Reduction_B(
#       (block0): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(1024, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), bias=False)
#           (bn): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#       )
#       (block1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(256, 256, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(256, 320, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#         (3): BasicConv2d(
#           (conv): Conv2d(320, 320, kernel_size=(3, 3), stride=(2, 2), bias=False)
#           (bn): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#       )
#       (block2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (19): Inception_C(
#       (block0): BasicConv2d(
#         (conv): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#       )
#       (block1_0): BasicConv2d(
#         (conv): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#       )
#       (block1_1a): BasicConv2d(
#         (conv): Conv2d(384, 256, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#       )
#       (block1_1b): BasicConv2d(
#         (conv): Conv2d(384, 256, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#         (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#       )
#       (block2_0): BasicConv2d(
#         (conv): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#       )
#       (block2_1): BasicConv2d(
#         (conv): Conv2d(384, 448, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#         (bn): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#       )
#       (block2_2): BasicConv2d(
#         (conv): Conv2d(448, 512, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#         (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#       )
#       (block2_3a): BasicConv2d(
#         (conv): Conv2d(512, 256, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#       )
#       (block2_3b): BasicConv2d(
#         (conv): Conv2d(512, 256, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#         (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#       )
#       (block3): Sequential(
#         (0): AvgPool2d(kernel_size=3, stride=1, padding=1)
#         (1): BasicConv2d(
#           (conv): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#       )
#     )
#     (20): Inception_C(
#       (block0): BasicConv2d(
#         (conv): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#       )
#       (block1_0): BasicConv2d(
#         (conv): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#       )
#       (block1_1a): BasicConv2d(
#         (conv): Conv2d(384, 256, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#       )
#       (block1_1b): BasicConv2d(
#         (conv): Conv2d(384, 256, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#         (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#       )
#       (block2_0): BasicConv2d(
#         (conv): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#       )
#       (block2_1): BasicConv2d(
#         (conv): Conv2d(384, 448, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#         (bn): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#       )
#       (block2_2): BasicConv2d(
#         (conv): Conv2d(448, 512, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#         (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#       )
#       (block2_3a): BasicConv2d(
#         (conv): Conv2d(512, 256, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#       )
#       (block2_3b): BasicConv2d(
#         (conv): Conv2d(512, 256, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#         (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#       )
#       (block3): Sequential(
#         (0): AvgPool2d(kernel_size=3, stride=1, padding=1)
#         (1): BasicConv2d(
#           (conv): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#       )
#     )
#     (21): Inception_C(
#       (block0): BasicConv2d(
#         (conv): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#       )
#       (block1_0): BasicConv2d(
#         (conv): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#       )
#       (block1_1a): BasicConv2d(
#         (conv): Conv2d(384, 256, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#       )
#       (block1_1b): BasicConv2d(
#         (conv): Conv2d(384, 256, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#         (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#       )
#       (block2_0): BasicConv2d(
#         (conv): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#       )
#       (block2_1): BasicConv2d(
#         (conv): Conv2d(384, 448, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#         (bn): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#       )
#       (block2_2): BasicConv2d(
#         (conv): Conv2d(448, 512, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#         (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#       )
#       (block2_3a): BasicConv2d(
#         (conv): Conv2d(512, 256, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#       )
#       (block2_3b): BasicConv2d(
#         (conv): Conv2d(512, 256, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#         (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#       )
#       (block3): Sequential(
#         (0): AvgPool2d(kernel_size=3, stride=1, padding=1)
#         (1): BasicConv2d(
#           (conv): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace)
#         )
#       )
#     )
#     (22): AdaptiveAvgPool2d(output_size=(1, 1))
#   )
#   (classif): Linear(in_features=1536, out_features=1001, bias=True)
# )

# %%
out = encoder(x.cpu())
out.size()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-216-19808f1556b9> in <module>()
# ----> 1 out = encoder(x.cpu())
#       2 out.size()
#
# ~/projects/jadlg_rnn/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# ~/projects/Seq2Seq-Workshop/notebooks/inceptionv4.py in forward(self, x)
#     255
#     256     def forward(self, x):
# --> 257         x = self.features(x)
#     258         x = x.view(x.size(0), -1)
#     259         x = self.classif(x)
#
# ~/projects/jadlg_rnn/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# ~/projects/jadlg_rnn/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      89     def forward(self, input):
#      90         for module in self._modules.values():
# ---> 91             input = module(input)
#      92         return input
#      93
#
# ~/projects/jadlg_rnn/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# ~/projects/Seq2Seq-Workshop/notebooks/inceptionv4.py in forward(self, x)
#      56         x0 = self.block0(x)
#      57         x1 = self.block1(x)
# ---> 58         out = torch.cat((x0, x1), 1)
#      59         return out
#      60
#
# RuntimeError: $ Torch: not enough memory: you tried to allocate 0GB. Buy new RAM! at /pytorch/aten/src/TH/THGeneral.cpp:204

# %%
import fastai
from fastai.conv_learner import *
# Out:
# /home/paperspace/projects/jadlg_rnn/lib/python3.6/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
import torchvision.transforms as transforms

# %%
tfms = tfms_from_model(inception_4, 224, transforms_side_on, max_zoom=1.1)

# %%
import spacy
from spacy.symbols import ORTH
en_tok = spacy.load('en')
def tokenize(text):
    text = text.lower()
    return [t.text for t in en_tok.tokenizer(text)]

# %%
from collections import Counter,defaultdict

# %%
def numericalize_tok(tokens, max_vocab=50000, min_freq=0, unk_tok="_unk_", pad_tok="_pad_", bos_tok="_bos_", eos_tok="_eos_"):
    if isinstance(tokens, str):
        raise ValueError("Expected to receive a list of tokens. Received a string instead")
    if isinstance(tokens[0], list):
        tokens = [p for o in tokens for p in o]
    freq = Counter(tokens)
    int2tok = [o for o,c in freq.most_common(max_vocab) if c>min_freq]
    unk_id = 3
    int2tok.insert(0, bos_tok)
    int2tok.insert(1, pad_tok)
    int2tok.insert(2, eos_tok)
    int2tok.insert(unk_id, unk_tok)
    tok2int = defaultdict(lambda:unk_id, {v:k for k,v in enumerate(int2tok)})
    return int2tok, tok2int

# %%
cap_toks_trn = list(df_trn['caption'])
cap_toks_val = list(df_val['caption'])
cap_toks_trn = [tokenize(cap) for cap in cap_toks_trn]
cap_toks_val = [tokenize(cap) for cap in cap_toks_val] 
itos,stoi = numericalize_tok(cap_toks_trn)

# %%
trn_x = list(df_trn['file_name'])
trn_x = ['train2014/'+x for x in trn_x]
val_x = list(df_val['file_name'])
val_x = ['val2014/'+x for x in val_x]

trn_y = [[0]+[stoi[o] for o in cap]+[2] for cap in cap_toks_trn]
val_y = [[0]+[stoi[o] for o in cap]+[2] for cap in cap_toks_val]

# %%
from keras.preprocessing.sequence import pad_sequences
# Out:
# Using TensorFlow backend.

# %%
trn_y = pad_sequences(trn_y, maxlen=25, dtype='int32', padding='post', truncating='post', value=1)
val_y = pad_sequences(val_y, maxlen=25, dtype='int32', padding='post', truncating='post', value=1)

# %%
trn_x[1], trn_y[1]
# Out:
# ('train2014/COCO_train2014_000000000009.jpg',
#  [4, 430, 12, 3660, 9, 1028, 403, 499, 1083, 5])

# %%
def get_c(self): return 1

# %%
fastai.dataset.ArraysIndexDataset.get_c = get_c

# %%
val_idxs = list(range(len(trn_x), len(trn_x)+len(val_x)))

# %%
md = ImageClassifierData.from_names_and_array(path,trn_x+val_x,np.concatenate((trn_y,val_y),0),
                                              val_idxs=val_idxs,tfms=tfms,continuous=True,classes=None, bs=20)

# %%
x,y = next(iter(md.trn_dl))
#x[0].size(), y.size()

# %%
torch.stack(y,1).size()
# Out:
# torch.Size([128, 8])

# %%
x.size(),y.size()
# Out:
# (torch.Size([20, 3, 224, 224]), torch.Size([20, 25]))

# %%
denorm = md.val_ds.denorm

def show_img(im, figsize=None, ax=None):
    if not ax: fig,ax = plt.subplots(figsize=figsize)
    ax.imshow(im)
    ax.axis('off')
    return ax

def show_imgs(ims, cols, figsize=None):
    fig,axes = plt.subplots(len(ims)//cols, cols, figsize=figsize)
    for i,ax in enumerate(axes.flat): show_img(ims[i], ax=ax)
    plt.tight_layout()

# %%
x[0].size()
# Out:
# torch.Size([3, 224, 224])

# %%
show_img(denorm(x)[0])

# %%
[itos[o] for o in y[0] if o not in [0,1,2]]
# Out:
# ['a', 'laptop', 'turned', 'on', 'laying', 'on', 'a', 'bed']

# %%
#import math,random

#def rand_t(*sz): return torch.randn(sz)/math.sqrt(sz[0])
#def rand_p(*sz): return nn.Parameter(rand_t(*sz))

# %%
class Seq2Seq(nn.Module):
    def __init__(self,inceptionnet,en_vecs,int2en,em_sz,nh=128,out_sl=25,dropf=1,nl=2):
        super().__init__()
        self.nl,self.nh,self.em_sz,self.out_sl = nl,nh,em_sz,out_sl
        #encoder
        self.inceptionnet = inceptionnet
        self.feat_sz = inceptionnet.classif.in_features
        modules = list(inceptionnet.children())[:-1] # delete the last fc layer.
        self.inceptionnet = nn.Sequential(*modules)
        self.bn = nn.BatchNorm1d(nh, momentum=0.01)
        self.out_enc = nn.Linear(self.feat_sz, nh)
        #decoder
        self.emb_dec = create_emb(en_vecs,int2en,em_sz)
        self.decoder = nn.GRU(em_sz,nh,num_layers=nl,dropout=0.25*dropf)
        self.out_drop = nn.Dropout(0.35*dropf)
        self.out = nn.Linear(nh,len(int2en))
        self.l3 = nn.Linear(dim_en_vec+nh, dim_en_vec)
    
    def forward(self,inp,y=None):
        bs,_,_,_ = inp.size()
        #emb_in = self.emb_drop(self.emb_enc(inp))
        with torch.no_grad():
            feat_out = self.inceptionnet(inp).view(bs,self.feat_sz)
        enc_out = self.bn(self.out_enc(feat_out))
        h_n = self.initHidden(bs)
        #h_n = h_n.view(2,2,bs,-1).permute(0,2,1,3).contiguous().view(self.nl,bs,-1)
        
        dec_inp = V(torch.zeros(bs).long())
        res = []
        for i in range(self.out_sl):
            dec_emb = self.emb_dec(dec_inp)
            wgt_enc = self.l3(torch.cat([dec_emb, enc_out], 1))
            outp,h_n = self.decoder(wgt_enc.unsqueeze(0),h_n)
            outp = self.out(self.out_drop(outp[0]))
            res.append(outp)
            dec_inp = outp.data.max(1)[1]
            if (random.random() > 0.5) and y is not None: dec_inp=y[i] 
            if (dec_inp==1).all(): break
        return torch.stack(res)
        
    def initHidden(self,bs):
        return V(torch.zeros([self.nl,bs,self.nh]))

# %%
import fastai
fastai.core.USE_GPU=False

# %%
import io
def load_vectors(fname):
    fin = io.open(fname, 'r', encoding='utf-8', newline='\n', errors='ignore')
    header = fin.readline().split()
    n, d = int(header[0]), int(header[1])
    data = {}
    for line in fin:
        tokens = line.rstrip().split(' ')
        data[tokens[0]] = np.array(tokens[1:], dtype=float)
    return data, n, d

# %%
en_vecs,_,dim_en_vec = load_vectors('../data/wiki-news-300d-1M.vec')

# %%
def create_emb(vecs, itos, em_sz):
    emb = nn.Embedding(len(itos), em_sz, padding_idx=1)
    wgts = emb.weight.data
    miss = []
    for i,w in enumerate(itos):
        try: wgts[i] = torch.from_numpy(vecs[w])
        except: miss.append(w)
    print('Number of unknowns in data: {}'.format(len(miss)))
    return emb

# %%
seq2seq = Seq2Seq(encoder,en_vecs,itos,dim_en_vec)
# Out:
# Number of unknowns in data: 3539

# %%
out = seq2seq(x.cpu())

# %%
out.size()
# Out:
# torch.Size([25, 20, 23480])

# %%
def seq2seq_loss(input, target):
    sl,bs = target.size()
    sl_in,bs_in,nc = input.size()
    if sl>sl_in: input = F.pad(input, (0,0,0,0,0,sl-sl_in))
    input = input[:sl]
    return F.cross_entropy(input.contiguous().view(-1,nc), target.contiguous().view(-1))

# %%
y.size()
# Out:
# torch.Size([20, 8])

# %%
seq2seq_loss(out,y.transpose(1,0).cpu())
# Out:
# tensor(10.1177, grad_fn=<NllLossBackward>)

# %%
def step(x, y, epoch, m, crit, opt, clip=None):
    output = m(x, y)
    opt.zero_grad()
    loss = crit(output, y)
    loss.backward()
    if clip:
        nn.utils.clip_grad_norm_(m.parameters(), clip)
    opt.step()
    return loss.data.item()

# %%
def train(trn_dl,val_dl,model,crit,opt,epochs=10,clip=None):
    for epoch in range(epochs):
        loss_val = loss_trn = 0
        with tqdm(total=len(trn_dl)) as pbar:
            model.train()
            for i, ds in enumerate(trn_dl):
                x, y = ds
                y = y.transpose(1,0)
                loss = step(x,y,epoch,model,crit,opt)
                loss_trn += loss
                pbar.update()
        model.eval()
        for i, ds in enumerate(val_dl):
            with torch.no_grad():
                x, y = ds
                y = y.transpose(1,0)
                out = model(x)
                loss_val+= crit(out, V(y.long()))
                #loss_val +=loss
        print(f'Epoch: {epoch} trn loss: {loss_trn/len(trn_dl)} val loss: {loss_val/len(val_dl)}')

# %%
opt = optim.Adam(seq2seq.parameters(),lr=3e-3,betas=(0.7,0.8))

# %%
train(md.trn_dl,md.val_dl,seq2seq,seq2seq_loss,opt,epochs=2)
# Out:
#   0%|          | 4/20706 [00:25<37:39:00,  6.55s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-113-dd9730167d5f> in <module>()
# ----> 1 train(md.trn_dl,md.val_dl,seq2seq,seq2seq_loss,opt,epochs=2)
#
# <ipython-input-112-0dbc0162a982> in train(trn_dl, val_dl, model, crit, opt, epochs, clip)
#       7                 x, y = ds
#       8                 y = y.transpose(1,0)
# ----> 9                 loss = step(x,y,epoch,model,crit,opt)
#      10                 loss_trn += loss
#      11                 pbar.update()
#
# <ipython-input-109-16c1c05ec707> in step(x, y, epoch, m, crit, opt, clip)
#       1 def step(x, y, epoch, m, crit, opt, clip=None):
# ----> 2     output = m(x, y)
#       3     opt.zero_grad()
#       4     loss = crit(output, y)
#       5     loss.backward()
#
# ~/projects/jadlg_rnn/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# <ipython-input-103-845909302504> in forward(self, inp, y)
#      21         #emb_in = self.emb_drop(self.emb_enc(inp))
#      22         with torch.no_grad():
# ---> 23             feat_out = self.inceptionnet(inp).view(bs,self.feat_sz)
#      24         enc_out = self.bn(self.out_enc(feat_out))
#      25         h_n = self.initHidden(bs)
#
# ~/projects/jadlg_rnn/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# ~/projects/jadlg_rnn/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      89     def forward(self, input):
#      90         for module in self._modules.values():
# ---> 91             input = module(input)
#      92         return input
#      93
#
# ~/projects/jadlg_rnn/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# ~/projects/jadlg_rnn/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      89     def forward(self, input):
#      90         for module in self._modules.values():
# ---> 91             input = module(input)
#      92         return input
#      93
#
# ~/projects/jadlg_rnn/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# ~/projects/Seq2Seq-Workshop/notebooks/inceptionv4.py in forward(self, x)
#     150     def forward(self, x):
#     151         x0 = self.block0(x)
# --> 152         x1 = self.block1(x)
#     153         x2 = self.block2(x)
#     154         x3 = self.block3(x)
#
# ~/projects/jadlg_rnn/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# ~/projects/jadlg_rnn/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      89     def forward(self, input):
#      90         for module in self._modules.values():
# ---> 91             input = module(input)
#      92         return input
#      93
#
# ~/projects/jadlg_rnn/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# ~/projects/Seq2Seq-Workshop/notebooks/inceptionv4.py in forward(self, x)
#      18
#      19     def forward(self, x):
# ---> 20         x = self.conv(x)
#      21         x = self.bn(x)
#      22         x = self.relu(x)
#
# ~/projects/jadlg_rnn/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# ~/projects/jadlg_rnn/lib/python3.6/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     299     def forward(self, input):
#     300         return F.conv2d(input, self.weight, self.bias, self.stride,
# --> 301                         self.padding, self.dilation, self.groups)
#     302
#     303
#
# KeyboardInterrupt:
